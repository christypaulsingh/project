# %%
class bank:
    count=0;
    accountN=1000023456
    reg=[]
    def __init__(self,name,pin,mobile,amount):
        self.name=name
        self.pin=pin
        self.mobile=mobile
        self.amount=amount
        self.accountNum=bank.accountN
        
        bank.count=bank.count+1
        bank.accountN=bank.accountN+1
        
    def validation(self):
        print("*"*80)
        if self.name and self.name.isalpha() and self.pin and self.pin.isdigit() and len(self.pin)==4 and len(self.mobile)==10:
            print("Account create successfully - Acccount Number -",self.accountNum)
        else:
            print("Invalid detail! please enter again")
        print("*"*80)

            
    def printall(self):
        create={
            "Name":self.name,
            "Pin":self.pin,
            "Mobile":self.mobile,
            "Inital amount": self.amount,
            "Account number":self.accountNum
        }
        bank.reg.append(create)
        
    def deposite(self):
        print("*"*80)
        dp="DEPOSITE MONEY"
        print(dp.center(80,"*"))
        print("*"*80)
        money=int(input("Enter the deposite money:"))
        if money>0:
            self.amount=self.amount+money
            print("Successfully deposite money--Current balance:",self.amount)
        else:
            print("Sorry! it is not deposite the amount")
        print("*"*80)

            
    def withdrew(self):
        print("*"*80)
        dp="WITHDREW MONEY"
        print(dp.center(80,"*"))
        print("*"*80)
        money=int(input("Enter the withdrew money:"))
        if money>0 and self.amount>money:
            self.amount=self.amount-money
            print("Successfully withdrew money--Current balance:",self.amount)
        else:
            print("Sorry! it is not withdrew the amount") 
        print("*"*80)
        
    def statement(self):
        print("*"*80)
        dp="ACCOUNT STATEMENT"
        print(dp.center(80,"*"))
        print("*"*80)
        print("Account Name:",self.name)
        print("Account Pin number:",self.pin)
        print("Account number:",self.accountNum)
        print("Account mobile number",self.mobile)
        print("Account balance amount:",self.amount)
        print("*"*80)


        

            
print("*"*80)
la="Welcome to India bank"
print(la.center(80,"*"))
print("*"*80)

msg="""1.New account----2.Deposite money----3.Withdrew money----4.Account statement----5.Close"""
print(msg)
print("*"*80)
while True:
    ch=int(input("Enter the number:"))
    if ch==1:
        name=input("Enter your name:")
        pin=input("Enter the pin number (4-digit):")
        mobile=input("Enter the mobile number(10-digit):")
        amount=int(input("Enter the inital amount:"))
        
        reg=bank(name,pin,mobile,amount)
        reg.validation()
        reg.printall()
    if ch==2:
        reg.deposite()
    if ch==3:
        reg.withdrew()
    if ch==4:
        reg.statement()
    if ch==5:
        quit()
        break
# Out:
# ********************************************************************************
# *****************************Welcome to India bank******************************
# ********************************************************************************
# 1.New account----2.Deposite money----3.Withdrew money----4.Account statement----5.Close
# ********************************************************************************
# Enter the number:1
# Enter your name:Ram
# Enter the pin number (4-digit):1234
# Enter the mobile number(10-digit):9046784736
# Enter the inital amount:4500
# ********************************************************************************
# Account create successfully - Acccount Number - 1000023456
# ********************************************************************************
# Enter the number:2
# ********************************************************************************
# *********************************DEPOSITE MONEY*********************************
# ...
